# %% [markdown]
# # 02 - Data Cleaning & Preprocessing
#
# This notebook prepares the **Silver-layer dataset** used throughout the modeling workflow.
# Based on the insights from the EDA notebook, we:
#
# - Normalize column names
# - Inspect and standardize categorical values
# - Drop duplicate rows
# - Map categorical variables into usable numerical formats
# - Handle domain-specific variables (`pdays`, `month`, `day_of_week`)
# - Remove leakage features (not usable at prediction time)
# - Save a clean, modeling-ready dataset to the **Silver** directory
#
# The goal is to create a **reliable and consistent preprocessing pipeline** aligned with our modeling notebooks and identified business constraints.

# %% [markdown]
# # 1. Reading the Raw (Bronze) Dataset
#
# We begin by reading the raw CSV from the **Bronze layer** and applying column normalization using utilities defined in `utils.py`.
#
# This ensures:
#
# - Consistent column naming
# - No spaces or special characters
# - Predictable schema for downstream steps

# %%
# --- Basic Imports ---
from utils import *

# %% [markdown]
# ## 1.1 Normalize Columns & Inspect Dataset
#
# We inspect:
#
# - Dataset dimensions
# - Column names
# - Data types
# - Null / missing values
# - Categorical vs numerical structure
#
# **Goal:**
# Validate data integrity and confirm the dataset matches expectations from the EDA step.

# %%
df = pd.read_csv(os.path.join(BRONZE_PATH, 'bank-additional-full.csv'), sep=';')
df.columns = [normalizeString(colname) for colname in df.columns]

# %%
print("Dataframe shape:", df.shape)
pprint(("Columns:", df.columns.tolist()), compact=True)
print((df.info()))
print(df.shape)

# %% [markdown]
# # 2. Inspect and Validate Categorical Variables
#
# Categorical variables often contain:
#
# - Spelling inconsistencies
# - Mixed casing
# - Rare categories
# - Placeholder values such as `"unknown"`
#
# To avoid encoding or modeling issues later, we list the unique values per column.
#
# **Goal:**
# Confirm categories are clean, predictable, and consistent with expectations from EDA.

# %%
cat_cols = df.select_dtypes(include=["object", "category"]).columns
max_values = 20

print(f"Found {len(cat_cols)} categorical columns.\n")

for col in cat_cols:
    uniques = df[col].unique()
    n_unique = len(uniques)
    
    print(f"--- {col} ---")
    print(f"Unique values ({n_unique}):")
    
    if n_unique <= max_values:
        pprint(sorted(uniques))
    else:
        pprint(sorted(uniques[:max_values]))
        print(f"... and {n_unique - max_values} more")
    
    print("\n")

# %% [markdown]
# # 3. Deduplicate Records
#
# Before any transformation, we remove duplicate rows.
#
# This ensures:
# - Cleaner training data
# - No repeated samples affecting model learning
# - Consistency across the ML pipeline
#
# Duplicates in this dataset are rare, but the check is important for data hygiene.

# %%
print(f'Ammount of duplicate rows: {df.duplicated(keep=False).sum()}')
print(f'Total rows: {len(df)}')

# %%
df = df.drop_duplicates()
print(f'Total rows after dropping duplicates: {len(df)}')

# %% [markdown]
# # 4. Normalize & Map Key Categorical Variables
#
# Based on EDA insights, several variables require domain-specific treatment:
#
# **`y` — Convert target to binary (1 = yes, 0 = no):** Using the helper `convert_target()` from `utils.py`.
#
# **`pdays` — Extremely skewed, effectively categorical:** EDA shows `pdays = 999` which means *never contacted before*. We convert this to a binary flag:
# - `0` → no previous contact
# - `1` → previously contacted
#
# **`month` — Ordered categorical:** We map month names to integers (`jan`→1, ..., `dec`→12). This preserves natural ordering and allows cyclic or seasonal encoding later.
#
# **`day_of_week` — Ordered categorical:** Mapped to integers (`mon`→1 … `fri`→5). Useful for models that leverage ordinal structures.
#
# **Preserve `"unknown"` values:** These may carry meaning (e.g., missing job type may correlate with outcomes).

# %%
# print unique values of pdays and respective ammount of unique values
df['pdays'].groupby(df['pdays']).size().sort_values(ascending=False)

# %%
month_map = {
    'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4,
    'may': 5, 'jun': 6, 'jul': 7, 'aug': 8,
    'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12
}
print(df['month'].unique())

dow_map = {
    'mon': 1, 'tue': 2, 'wed': 3, 'thu': 4, 'fri': 5
}
print(df['day_of_week'].unique())

# Convert target column
df = convert_target(df, target_col='y')

# Convert pdays into 0 or 1
df['pdays'] = df['pdays'].apply(lambda x: 0 if x == 999 else 1)

# Map month and day_of_week to numerical values for easier analysis and modeling
df['month'] = df['month'].map(month_map)
df['day_of_week'] = df['day_of_week'].map(dow_map)

# %% [markdown]
# # 5. Drop Leakage Features
#
# **Remove `duration`**
#
# As shown on the EDA phase, `duration` is **not available before making the call**, therefor using it causes severe **target leakage**, artificially inflating model performance, so it must be removed from all preprocessing and modeling steps.

# %%
df = df.drop(columns=['duration'])

# %% [markdown]
# # 6. Final Dataset Validation
#
# Before saving, we:
#
# - Reinspect dataset shape
# - Confirm cleaned column list
# - Validate dtypes
# - Ensure all categorical mappings were applied correctly
#
# This serves as a final quality checkpoint before exporting the Silver dataset.

# %%
print("Dataframe shape:", df.shape)
pprint(("Columns:", df.columns.tolist()), compact=True)
print((df.info()))
print(df.shape)

# %% [markdown]
# # 7. Save Cleaned Dataset (Silver Layer)
#
# We save the preprocessed dataset **without feature engineering** as:

# %%
df.to_csv(os.path.join(SILVER_PATH, 'base_dataset.csv'), sep=";", index=False)
